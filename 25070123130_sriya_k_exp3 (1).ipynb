# %%
# Exp: study of tupple in python
# sriya kolluru
#25070123130

tpl=(2,"sriya","true")

# %%
tpl1=("apple","banana","orange")
tpl1[1]="kiwi"

# %%
tpl=("apple",2,"true","orange","kiwi")
print(tpl[1:4])
# Out:
# (2, 'true', 'orange')

# %%
print(tpl[:3])
print(tpl[1:3])
# Out:
# ('apple', 2, 'true')
# (2, 'true')

# %%
tpl3=(10,)*5
print(tpl3)
# Out:
# (10, 10, 10, 10, 10)

# %%
list1=["symbiosis",]*5

print(list1)
# Out:
# ['symbiosis', 'symbiosis', 'symbiosis', 'symbiosis', 'symbiosis']

# %%
tpl4=("apple","banana","orange")
print("before:",id(tpl4))
tpl5=("mango",)
tpl4+=tpl5
print(tpl4)
print("after:",id(tpl4))
# Out:
# before: 138157061768384
# ('apple', 'banana', 'orange', 'mango')
# after: 138156116304464

# %%
tpl4=["apple","banana","orange"]
print("before:",id(tpl4))
tpl5=["mango",]
tpl4+=tpl5
print(tpl4)
print("after:",id(tpl4))
# Out:
# before: 138156116220864
# ['apple', 'banana', 'orange', 'mango']
# after: 138156116220864

# %%
marks=(78,85,66,88)
"maximum marks"
"minimum marks"
"total marks"
"no of students:"
"calculate average marks"
"sort the marks in ascending order"
print(sorted(marks))
# Out:
# [66, 78, 85, 88]

# %%
print(min(marks))
# Out:
# 66

# %%
print(len(marks))
# Out:
# 4

# %%
print(sum(marks))
# Out:
# 317

# %%
print(sum(marks)/len(marks))
# Out:
# 79.25

# %%
print(sum(marks)/len(marks))
# Out:
# 79.25

# %%
#Result Analysis
result=("maths",82,"A")
#unpack the tuple
subject, marks,grade = result
subject,marks,grade = result

# display the result details
print("subject:", subject)
print("marks:", marks)
print("grade:",grade)
#check for distinction
if marks >= 75:
  print("distinction")
# Out:
# subject: maths
# marks: 82
# grade: A
# distinction

# %%
attendance_input = input("Enter employee's weekly attendance record (e.g., 'PPAPAPA' for Present/Absent): ")
attendance_record = tuple(attendance_input.upper())
print(f"Employee's weekly attendance record: {attendance_record}")
present_days = attendance_record.count('P')
print(f"Total present days: {present_days}")
absent_days = attendance_record.count('A')
print(f"Total absent days: {absent_days}")
if absent_days > 0:
    print("Message: The employee was absent at least once during the week.")
# Out:
# Enter employee's weekly attendance record (e.g., 'PPAPAPA' for Present/Absent): pppapp
# Employee's weekly attendance record: ('P', 'P', 'P', 'A', 'P', 'P')
# Total present days: 5
# Total absent days: 1
# Message: The employee was absent at least once during the week.
